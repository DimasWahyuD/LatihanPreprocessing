# %% [markdown]
# <a href="https://colab.research.google.com/github/DimasWahyuD/LatihanPreprocessing/blob/main/preprocessing2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import chardet

# %%
#importdataset 
#pemanggilan Dataset datapemilukpu.csv
dataset= pd.read_csv('datapemilukpu.csv')
X = dataset.iloc[:,:-1].values
Y = dataset.iloc[:,-1].values
print(X)
print(Y)
# Out:
# [['HATI NURANI RAKYAT ' 'TOTO SUKISNO,BSc' 'L' ... 1 '1' 594]
#  ['HATI NURANI RAKYAT ' 'EDI PURYANTO,SH' 'L' ... 1 '2' 943]
#  ['HATI NURANI RAKYAT ' 'ELI RETNOWATI,SH' 'P' ... 1 '3' 1730]
#  ...
#  ['PARTAI BURUH' 'SITI JURIYAH' 'P' ... 6 '6' 72]
#  ['PARTAI BURUH' 'MOHAMAD SOLIKHUN' 'L' ... 6 '7' 52]
#  ['PARTAI BURUH' 'MEGENG' 'L' ... 6 '8' 397]]
# ['TIDAK' 'TIDAK' 'TIDAK' 'YA' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK'
#  'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK'
#  'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK'
#  'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK'
#  'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK'
#  'TIDAK' 'YA' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK'
#  'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK'
#  'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'YA' 'TIDAK'
# ...

# %%
#Menghilangkan  missing value
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
X[:, 1:3] = imputer.transform(X[:, 1:3])
#missing values = nilai data yang digunakan sebagai penanda bahwa nilai aslinya tidak ada 
#strategy : menggunakan rata-rata kolom mean bisa juga menggunakan median, most_frequent(modus) atau constant
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-4-eced6cc7cd55> in <module>()
#       2 from sklearn.impute import SimpleImputer
#       3 imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
# ----> 4 X[:, 1:3] = imputer.transform(X[:, 1:3])
#       5 #missing values = nilai data yang digunakan sebagai penanda bahwa nilai aslinya tidak ada
#       6 #strategy : menggunakan rata-rata kolom mean bisa juga menggunakan median, most_frequent(modus) atau constant
#
# /usr/local/lib/python3.7/dist-packages/sklearn/impute/_base.py in transform(self, X)
#     402             The input data to complete.
#     403         """
# --> 404         check_is_fitted(self)
#     405
#     406         X = self._validate_input(X)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     965
# ...

# %%
print(X)
# Out:
# [['HATI NURANI RAKYAT ' 'TOTO SUKISNO,BSc' 'L' ... 1 '1' 594]
#  ['HATI NURANI RAKYAT ' 'EDI PURYANTO,SH' 'L' ... 1 '2' 943]
#  ['HATI NURANI RAKYAT ' 'ELI RETNOWATI,SH' 'P' ... 1 '3' 1730]
#  ...
#  ['PARTAI BURUH' 'SITI JURIYAH' 'P' ... 6 '6' 72]
#  ['PARTAI BURUH' 'MOHAMAD SOLIKHUN' 'L' ... 6 '7' 52]
#  ['PARTAI BURUH' 'MEGENG' 'L' ... 6 '8' 397]]

# %%
#Enconding Data kategori(Atribut)
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough')
X = np.array(ct.fit_transform(X))
print(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sklearn/compose/_column_transformer.py in _hstack(self, Xs)
#     614                                             force_all_finite=False)
# --> 615                                 for X in Xs]
#     616             except ValueError:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/compose/_column_transformer.py in <listcomp>(.0)
#     614                                             force_all_finite=False)
# --> 615                                 for X in Xs]
#     616             except ValueError:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     530                 else:
# ...

# %%
#Encoding Data kategori(class/label)
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(Y)

print(Y)
# Out:
# ['TIDAK' 'TIDAK' 'TIDAK' 'YA' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK'
#  'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK'
#  'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK'
#  'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK'
#  'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK'
#  'TIDAK' 'YA' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK'
#  'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK'
#  'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'YA' 'TIDAK'
#  'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK'
#  'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK'
#  'YA' 'TIDAK' 'TIDAK' 'TIDAK' 'YA' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK'
#  'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'YA' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK'
#  'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'TIDAK' 'YA'
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state =1)
print(X_train)
print(X_test)
print(Y_train)
print(Y_test)
# Out:
# [['PARTAI BULAN BINTANG' 'MUNTASIR, SE' 'L' ... 2 '2' 2143]
#  ['PARTAI KEADILAN SEJAHTERA' 'EDI SULASTOMO' 'L' ... 2 '7' 159]
#  ['PARTAI DEMOKRASI INDONESIA PERJUANGAN' 'HARJO RASDI' 'L' ... 4 '7'
#   2173]
#  ...
#  ['PARTAI KEBANGKITAN INDONESIA' 'Drs.ALI IMRON' 'L' ... 2 '1' 1669]
#  ['PARTAI GOLONGAN KARYA' 'KETI KULMUBAROK' 'P' ... 2 '6' 425]
#  ['PARTAI PEDULI RAKYAT ' 'ROZIKIN' 'L' ... 5 '1' 1912]]
# [['PARTAI KEBANGKITAN BANGSA' 'SAYID AGIL' 'L' 'BUMIJAWA' 13 108961 8 3
#   '4' 2951]
#  ['PARTAI KEADILAN SEJAHTERA' 'DIDIN NUR SUPRIYADI, SHI' 'L' 'SLAWI' 8
#   48136 5 1 '9' 338]
#  ['PARTAI KEADILAN SEJAHTERA' 'RINI KUSRINI' 'P' 'Kec. WARUREJO' 8 48136
#   5 6 '9' 126]
#  ['PARTAI DEMOKRAT' 'ROKHANI' 'P' 'PAGERBARANG' 31 58683 6 4 '2' 761]
#  ['PARTAI AMANAT NASIONAL' 'SYAEKHUL BAKRI, SE' 'L' 'ADIWERNA' 9 43317 5
#   5 '5' 573]
#  ['PARTAI DEMOKRASI INDONESIA PERJUANGAN' 'INDRA SUTRISNO' 'L' 'KRAMAT'
#   28 143817 13 6 '2' 2759]
# ...

# %%
#Feature Scaling 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train[:, 3:] = sc.fit_transform(X_train[:, 3:])
X_test[:, 3:] = sc.trasnform(X_test[:, 3:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-3e97bc7eb442> in <module>()
#       2 from sklearn.preprocessing import StandardScaler
#       3 sc = StandardScaler()
# ----> 4 X_train[:, 3:] = sc.fit_transform(X_train[:, 3:])
#       5 X_test[:, 3:] = sc.trasnform(X_test[:, 3:])
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     667         # Reset internal state before fitting
#     668         self._reset()
# ...

# %%
print(X_train)
print(X_test)
# Out:
# [['PARTAI BULAN BINTANG' 'MUNTASIR, SE' 'L' ... 2 '2' 2143]
#  ['PARTAI KEADILAN SEJAHTERA' 'EDI SULASTOMO' 'L' ... 2 '7' 159]
#  ['PARTAI DEMOKRASI INDONESIA PERJUANGAN' 'HARJO RASDI' 'L' ... 4 '7'
#   2173]
#  ...
#  ['PARTAI KEBANGKITAN INDONESIA' 'Drs.ALI IMRON' 'L' ... 2 '1' 1669]
#  ['PARTAI GOLONGAN KARYA' 'KETI KULMUBAROK' 'P' ... 2 '6' 425]
#  ['PARTAI PEDULI RAKYAT ' 'ROZIKIN' 'L' ... 5 '1' 1912]]
# [['PARTAI KEBANGKITAN BANGSA' 'SAYID AGIL' 'L' 'BUMIJAWA' 13 108961 8 3
#   '4' 2951]
#  ['PARTAI KEADILAN SEJAHTERA' 'DIDIN NUR SUPRIYADI, SHI' 'L' 'SLAWI' 8
#   48136 5 1 '9' 338]
#  ['PARTAI KEADILAN SEJAHTERA' 'RINI KUSRINI' 'P' 'Kec. WARUREJO' 8 48136
#   5 6 '9' 126]
#  ['PARTAI DEMOKRAT' 'ROKHANI' 'P' 'PAGERBARANG' 31 58683 6 4 '2' 761]
#  ['PARTAI AMANAT NASIONAL' 'SYAEKHUL BAKRI, SE' 'L' 'ADIWERNA' 9 43317 5
#   5 '5' 573]
#  ['PARTAI DEMOKRASI INDONESIA PERJUANGAN' 'INDRA SUTRISNO' 'L' 'KRAMAT'
#   28 143817 13 6 '2' 2759]
# ...
